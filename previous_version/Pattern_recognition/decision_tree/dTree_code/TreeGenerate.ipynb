# %%
import numpy as np
import treetool as tl
import node as nde

attribute=['色泽','根蒂','敲声','纹理','脐部','触感','密度','含糖率','好瓜']
data=[['青绿','卷缩','浊响','清晰','凹陷','硬滑',0.697,0.460,'是'],
      ['乌黑','卷缩','沉闷','清晰','凹陷','硬滑',0.774,0.376,'是'],
      ['乌黑','卷缩','浊响','清晰','凹陷','硬滑',0.634,0.264,'是'],
      ['青绿','卷缩','沉闷','清晰','凹陷','硬滑',0.608,0.318,'是'],
      ['浅白','卷缩','浊响','清晰','凹陷','硬滑',0.556,0.215,'是'],
      ['青绿','稍卷','浊响','清晰','稍凹','软粘',0.403,0.237,'是'],
      ['乌黑','稍卷','浊响','稍糊','稍凹','软粘',0.481,0.149,'是'],
      ['乌黑','稍卷','浊响','清晰','稍凹','硬滑',0.437,0.211,'是'],
      ['乌黑','稍卷','沉闷','稍糊','稍凹','硬滑',0.666,0.091,'否'],
      ['青绿','硬挺','清脆','清晰','平坦','软粘',0.243,0.267,'否'],
      ['浅白','硬挺','清脆','模糊','平坦','硬滑',0.245,0.057,'否'],
      ['浅白','卷缩','浊响','模糊','平坦','软粘',0.343,0.099,'否'],
      ['青绿','稍卷','浊响','稍糊','凹陷','硬滑',0.639,0.161,'否'],
      ['浅白','稍卷','沉闷','稍糊','凹陷','硬滑',0.657,0.198,'否'],
      ['乌黑','稍卷','浊响','清晰','稍凹','软粘',0.360,0.370,'否'],
      ['浅白','卷缩','浊响','模糊','平坦','硬滑',0.593,0.042,'否'],
      ['青绿','卷缩','沉闷','稍糊','稍凹','硬滑',0.719,0.103,'否'],
     ]




tls=tl.treetools(np.array(attribute),np.array(data),'好瓜')


start=nde.node('开始',0,0)
attribute11=['色泽','根蒂','敲声','纹理','脐部','触感','密度','含糖率']
tls.generateTree(np.array(attribute11),np.array(data),tls,'坏瓜',start,0)

tls.printTree(start,0)

dd=  ['青绿','卷缩','浊响','清晰','凹陷','硬滑',0.697,0.460,'是']
num1=0
for i in range(len(data)):
      b,c=tls.predicate((start.get_childrens())[0],np.array(data[i]))

      if(c==(data[i])[8]):
            num1+=1
print('准确率：%f'%(num1/len(data)))



#tain数据集

att11=[1,2,3]
Traindata1=[[0.61379,-1.133,1],
[-0.58545,-2.9982,1],
[2.4624,0.65745,1],
[2.487,-0.63792,1],
[-0.40453,0.97469,1],
[-0.10134,-2.1137,1],
[2.4979,0.45838,1],
[3.4658,3.2343,1],
[3.9182,2.2501,1],
[0.70138,-0.67003,1],
[2.8551,1.0144,1],
[2.8687,3.3771,1],
[1.9546,1.6928,1],
[0.51243,-2.3707,1],
[0.43803,-0.55476,1],
[3.0473,1.8278,1],
[-0.3788,-3.0692,1],
[1.5829,0.145,1],
[2.1987,0.015848,1],
[3.5457,1.126,1],
[-1.1385,4.6973,2],
[-2.5837,2.7697,2],
[-1.5166,1.4162,2],
[2.6515,2.5877,2],
[-0.18347,1.556,2],
[-1.3457,3.0627,2],
[2.0759,0.24931,2],
[1.2996,-0.5712,2],
[-1.2199,1.4497,2],
[1.5202,2.8471,2],
[1.5703,0.70639,2],
[-1.0943,2.3632,2],
[0.76351,1.9857,2],
[-0.52431,3.7035,2],
[1.7689,1.3022,2],
[-1.7848,2.5758,2],
[-0.57775,1.2448,2],
[1.1608,2.1334,2],
[-0.11248,-0.5014,2],
[0.81514,0.15338,2],]

abc=np.array(Traindata1)

(abc[:,2])[(abc[:,2])==2]=(-1)
print(abc)

tls1111=tl.treetools(np.array(att11),np.array(Traindata1),3)


start1111=nde.node('开始',0,0)
Trainattribute11=[1,2]
tls1111.generateTree(np.array(Trainattribute11),np.array(Traindata1),tls1111,-1,start1111,0)

tls1111.printTree(start1111,0)





testdata=[[1.4434,0.059728,1],
[-1.0778,-0.97575,1],
[0.30909,-1.1118,1],
[2.5167,1.2334,1],
[5.4117,-0.15334,1],
[3.0469,-0.79307,1],
[2.438,-3.5436,1],
[1.2335,0.25535,1],
[2.1729,-1.1273,1],
[3.3609,0.37042,1],
[1.6408,1.0565,1],
[4.6753,1.4002,1],
[0.2743,-1.4023,1],
[1.4679,-1.3052,1],
[2.0741,-0.25732,1],
[-0.76328,-0.64321,1],
[2.7996,-1.4572,1],
[2.11,-0.0287,1],
[2.1141,1.0153,1],
[3.1239,-1.1781,1],
[3.476,1.5578,1],
[3.1345,1.404,1],
[1.337,-1.4119,1],
[1.9341,-1.8756,1],
[2.4999,0.78041,1],
[0.22262,0.10121,1],
[0.53483,-0.023534,1],
[1.3962,0.63239,1],
[2.1098,-1.3929,1],
[4.5328,1.9814,1],
[3.1275,-0.14661,1],
[1.3742,-1.0004,1],
[1.1103,-2.3504,1],
[4.1691,2.432,1],
[5.8658,2.1473,1],
[2.2368,1.3476,1],
[1.3228,1.512,1],
[0.0022057,-2.3917,1],
[3.3788,1.477,1],
[2.4097,0.18923,1],
[3.6481,1.9438,1],
[0.7149,0.71409,1],
[2.3402,1.175,1],
[1.075,-1.4638,1],
[3.8031,0.74662,1],
[1.2205,-0.066243,1],
[1.8764,3.8066,1],
[1.5081,1.2563,1],
[3.4057,3.545,1],
[2.6059,0.8106,1],
[0.57987,-0.45063,1],
[1.1052,0.3036,1],
[0.52114,-1.3858,1],
[2.7152,1.8782,1],
[2.4695,0.041669,1],
[-0.31282,-2.8387,1],
[-0.69668,-0.28179,1],
[1.9429,-1.9496,1],
[2.986,-1.7657,1],
[2.2387,0.47259,1],
[-0.18326,-2.2563,1],
[-0.19458,-2.2127,1],
[3.2262,0.41477,1],
[1.7944,-0.70157,1],
[1.4538,-0.54597,1],
[3.8614,1.2639,1],
[0.87363,-1.9943,1],
[2.1915,-1.4036,1],
[2.5909,-2.2759,1],
[3.1595,0.10179,1],
[0.79176,0.20946,1],
[2.5053,-0.60743,1],
[5.8869,2.5575,1],
[-0.13967,-0.40809,1],
[2.6137,1.5203,1],
[1.6751,1.0493,1],
[0.83032,-1.4285,1],
[0.8234,-1.6377,1],
[2.7041,0.41133,1],
[5.2748,0.82312,1],
[0.87736,1.2179,1],
[2.765,2.0725,1],
[1.2094,-0.2788,1],
[4.7953,0.87452,1],
[2.7703,1.0107,1],
[1.805,-0.90128,1],
[2.8766,0.2852,1],
[1.9921,-0.65363,1],
[3.5658,0.91222,1],
[1.7375,1.2507,1],
[0.41408,0.11638,1],
[2.3485,1.5749,1],
[4.2076,-0.016472,1],
[0.30772,-0.62593,1],
[1.6573,-1.3757,1],
[3.421,1.1818,1],
[-0.71547,-0.95884,1],
[2.8845,2.0299,1],
[3.0648,1.8787,1],
[2.3019,0.95099,1],
[0.91072,-1.1632,1],
[1.9899,-0.58802,1],
[2.1318,-2.4467,1],
[3.3226,0.11226,1],
[2.9384,-1.4306,1],
[1.5047,0.89115,1],
[4.2909,2.2501,1],
[1.9281,0.13342,1],
[0.85067,-1.0381,1],
[1.38,-0.13479,1],
[3.2143,2.5729,1],
[2.2761,1.7904,1],
[3.257,0.079293,1],
[2.0979,0.25521,1],
[5.5169,0.38613,1],
[-0.35558,-0.68699,1],
[1.4118,0.61106,1],
[1.8809,1.0428,1],
[2.1262,-1.8122,1],
[4.0593,1.6477,1],
[2.3104,-0.90327,1],
[1.8375,-0.54241,1],
[2.097,1.0136,1],
[3.0628,0.89661,1],
[1.025,-0.68804,1],
[2.6375,1.0619,1],
[-0.21328,0.8952,1],
[1.8886,-0.81934,1],
[0.66811,-2.3195,1],
[1.0767,-1.8851,1],
[2.3996,-0.95672,1],
[0.4089,-1.6176,1],
[0.60138,0.006977,1],
[-0.14375,-3.6264,1],
[-1.1516,-1.2868,1],
[1.7857,-1.0605,1],
[3.6444,2.1689,1],
[1.7427,-1.1765,1],
[1.6691,-0.15617,1],
[0.51969,-1.8885,1],
[4.2392,0.28484,1],
[1.6473,-0.49497,1],
[3.83,0.63479,1],
[2.5119,-0.3868,1],
[1.628,1.1959,1],
[3.5304,1.439,1],
[3.3894,2.9668,1],
[1.8424,-0.41842,1],
[3.8328,2.2227,1],
[4.5191,-1.3115,1],
[1.9072,0.73558,1],
[1.6384,0.27416,1],
[2.5722,-0.17215,1],
[2.4975,1.1004,1],
[3.142,1.6459,1],
[1.6385,1.0852,1],
[3.0113,1.0198,1],
[3.4829,1.4776,1],
[2.2511,-0.69995,1],
[2.2168,-1.2329,1],
[0.22612,-1.2147,1],
[0.34141,-0.60082,1],
[-0.066791,0.13127,1],
[0.24031,-1.848,1],
[1.7807,-0.70916,1],
[-0.28383,2.5011,1],
[5.1764,0.8257,1],
[3.0455,2.8746,1],
[-0.92409,-0.28488,1],
[0.36722,-1.4996,1],
[1.8484,-0.2063,1],
[-0.42238,-1.4747,1],
[1.3496,0.25471,1],
[3.5429,2.444,1],
[1.7682,-2.1218,1],
[1.9049,2.431,1],
[0.58353,0.24436,1],
[1.2142,-1.0652,1],
[0.088611,-1.11,1],
[2.5151,0.62445,1],
[1.3605,0.042975,1],
[3.1078,2.0246,1],
[3.7497,2.21,1],
[3.5234,0.32237,1],
[1.9507,-0.18376,1],
[1.2873,0.54227,1],
[0.26898,-0.71814,1],
[2.1676,1.4755,1],
[3.3569,-0.16267,1],
[1.5179,0.33662,1],
[1.7549,0.23059,1],
[2.8716,2.1405,1],
[3.2218,-1.037,1],
[-0.0038192,-1.001,1],
[2.2828,0.2069,1],
[2.2769,-2.7298,1],
[1.7863,1.4217,1],
[3.2626,4.0719,1],
[1.485,-0.54189,1],
[0.83159,-0.23266,1],
[-0.65705,3.2878,2],
[0.54351,1.3479,2],
[-0.53716,3.0712,2],
[-0.14394,1.4137,2],
[2.2884,1.2583,2],
[-1.1982,3.8901,2],
[-0.81442,-0.017416,2],
[-0.10736,-0.2334,2],
[-0.18734,-0.1505,2],
[2.0355,2.0216,2],
[2.8726,1.0599,2],
[-1.3834,1.8314,2],
[-0.90654,4.2892,2],
[0.73606,1.8007,2],
[-0.53839,0.32574,2],
[2.8183,-0.65735,2],
[2.3135,-0.85329,2],
[0.79057,2.7742,2],
[0.7971,0.86523,2],
[-0.47857,0.80402,2],
[1.08,0.75321,2],
[1.5944,0.17836,2],
[0.20021,2.9446,2],
[2.7268,1.2212,2],
[0.94843,1.8961,2],
[-0.15572,2.5871,2],
[0.52462,1.7903,2],
[1.5508,0.062487,2],
[-0.56309,2.9449,2],
[-0.12086,1.0548,2],
[3.3563,-0.99098,2],
[-0.67023,1.0196,2],
[1.3383,2.3958,2],
[1.1571,2.623,2],
[2.2471,-1.2777,2],
[0.74389,1.4467,2],
[-3.4863,4.0517,2],
[-1.2057,1.8553,2],
[0.7237,2.5702,2],
[0.36455,2.1293,2],
[2.7753,0.42516,2],
[1.9888,0.3229,2],
[0.70263,2.4779,2],
[0.11714,2.9816,2],
[-2.1899,3.6697,2],
[2.6349,0.38888,2],
[0.18954,3.0332,2],
[-2.1864,1.9825,2],
[0.61275,1.8705,2],
[0.1456,3.6374,2],
[-0.80659,2.171,2],
[0.6973,0.61787,2],
[-1.0006,4.8805,2],
[-1.9064,2.6508,2],
[-2.481,3.7813,2],
[-0.5145,1.273,2],
[-0.88684,2.7957,2],
[0.62247,2.2607,2],
[-2.1251,3.0681,2],
[-0.29449,2.5466,2],
[-2.1286,4.5396,2],
[2.5594,-0.99936,2],
[-0.16542,2.3345,2],
[1.7341,-1.3058,2],
[0.69996,1.6848,2],
[1.2849,3.7219,2],
[-1.6323,3.9688,2],
[1.7785,1.1023,2],
[2.0542,0.55864,2],
[-2.9371,4.1155,2],
[-0.24959,3.4192,2],
[-0.92218,2.4791,2],
[0.22137,3.867,2],
[-1.2024,1.602,2],
[0.39463,-0.64406,2],
[0.84442,0.66145,2],
[0.34608,1.5829,2],
[-0.16737,1.6271,2],
[-1.8235,1.8739,2],
[0.081407,3.5971,2],
[-0.73671,0.38878,2],
[-1.8088,2.3021,2],
[-0.079517,0.85261,2],
[-0.29653,1.5676,2],
[0.27167,1.0483,2],
[1.4034,1.8842,2],
[0.81493,0.3175,2],
[1.8467,0.071573,2],
[-1.0314,2.6396,2],
[-1.2227,3.9389,2],
[-0.13424,-0.2042,2],
[1.9562,3.2262,2],
[1.8437,0.0023736,2],
[-0.17793,2.8823,2],
[-0.84411,3.7075,2],
[-2.1505,4.6957,2],
[0.95013,0.8913,2],
[0.032307,2.0136,2],
[-1.6656,2.634,2],
[-0.47316,1.4948,2],
[-2.5872,3.6264,2],
[0.6081,2.1352,2],
[-0.24606,1.6915,2],
[2.3069,1.0086,2],
[-1.9225,6.2357,2],
[1.3725,1.3045,2],
[0.20314,2.7684,2],
[0.11682,1.3751,2],
[1.0135,0.84673,2],
[1.6878,0.73258,2],
[-1.5147,3.4488,2],
[1.8652,0.085714,2],
[-1.7112,0.58621,2],
[-1.519,2.8247,2],
[-0.95114,1.9411,2],
[1.0415,1.8222,2],
[-1.5132,2.8602,2],
[0.47336,2.6563,2],
[0.58249,2.8119,2],
[0.21796,0.26745,2],
[0.78428,-0.25936,2],
[-1.6587,3.4447,2],
[1.4249,1.6628,2],
[0.16054,0.7695,2],
[1.0324,2.9993,2],
[-1.3909,2.7359,2],
[0.073584,2.1145,2],
[1.2411,1.7149,2],
[1.4342,2.2066,2],
[-0.11929,3.9268,2],
[-2.6213,2.9898,2],
[-1.5511,0.65592,2],
[0.30919,3.0866,2],
[1.1232,0.30214,2],
[0.65496,3.1957,2],
[-0.86639,1.7112,2],
[3.1741,2.2397,2],
[0.10231,0.96172,2],
[1.224,0.025339,2],
[-0.58788,3.4659,2],
[-1.5768,1.119,2],
[0.96909,2.349,2],
[1.4675,1.8025,2],
[2.577,0.53604,2],
[-0.7481,1.9558,2],
[-2.3023,5.6714,2],
[2.2872,0.39768,2],
[0.37355,1.5803,2],
[-1.594,1.6473,2],
[-0.79079,1.3991,2],
[-1.1439,1.8572,2],
[1.6419,3.2728,2],
[0.83736,1.1032,2],
[0.3433,0.9832,2],
[0.34009,1.281,2],
[-1.1618,3.4558,2],
[1.4045,-0.31367,2],
[0.48988,2.5231,2],
[-0.3693,0.55415,2],
[-0.26122,1.9704,2],
[-0.14388,-0.16554,2],
[-1.2545,3.2836,2],
[1.0485,2.3243,2],
[1.9689,0.17349,2],
[3.4986,0.63964,2],
[0.71265,1.8431,2],
[-1.1632,4.0012,2],
[0.28423,2.0151,2],
[-1.4242,3.9852,2],
[-0.86716,2.2906,2],
[-0.93191,1.672,2],
[-1.1784,2.5427,2],
[0.53483,1.4885,2],
[-1.5773,3.8685,2],
[0.94362,1.4594,2],
[1.1248,0.40731,2],
[1.4672,1.0767,2],
[-0.028894,3.4702,2],
[0.87533,1.0542,2],
[2.5499,-0.081596,2],
[0.074944,3.1677,2],
[-0.25157,2.2498,2],
[2.5067,0.30244,2],
[-3.548,2.8691,2],
[-0.64571,0.51043,2],
[3.4371,0.4693,2],
[-0.66674,1.9451,2],
[-0.79242,2.7868,2],
[-1.7345,1.0833,2],
[1.1214,3.0582,2],
[-2.9839,4.0887,2],
[-1.1305,0.64654,2],
[0.80182,2.8937,2],
[-0.0020406,1.2814,2],
[0.88236,1.929,2],
[0.17881,2.1794,2],
[0.96289,0.44298,2],
[-1.8207,-0.59414,2],
[0.30842,2.5017,2],
[-2.2155,2.6888,2],]

testnum1=0
for i in range(len(testdata)):
      b,c=tls1111.predicate((start1111.get_childrens())[0],np.array(testdata[i]))
      if(c==(testdata[i])[2]):
            testnum1+=1
print('准确率：%f'%(testnum1/len(testdata)))
# Out:
# 层数0,('开始', 0, 0)
# 层数1,('纹理', -1, 0)
# 层数2,('密度', 0.3815, '清晰')
# 层数3,('好瓜', '否', '-')
# 层数3,('好瓜', '是', '+')
# 层数2,('触感', -1, '稍糊')
# 层数3,('好瓜', '是', '软粘')
# 层数3,('好瓜', '否', '硬滑')
# 层数2,('好瓜', '否', '模糊')
# 准确率：1.000000
# [[ 0.61379  -1.133     1.      ]
#  [-0.58545  -2.9982    1.      ]
#  [ 2.4624    0.65745   1.      ]
#  [ 2.487    -0.63792   1.      ]
#  [-0.40453   0.97469   1.      ]
#  [-0.10134  -2.1137    1.      ]
#  [ 2.4979    0.45838   1.      ]
#  [ 3.4658    3.2343    1.      ]
#  [ 3.9182    2.2501    1.      ]
#  [ 0.70138  -0.67003   1.      ]
#  [ 2.8551    1.0144    1.      ]
#  [ 2.8687    3.3771    1.      ]
#  [ 1.9546    1.6928    1.      ]
#  [ 0.51243  -2.3707    1.      ]
#  [ 0.43803  -0.55476   1.      ]
#  [ 3.0473    1.8278    1.      ]
#  [-0.3788   -3.0692    1.      ]
#  [ 1.5829    0.145     1.      ]
#  [ 2.1987    0.015848  1.      ]
#  [ 3.5457    1.126     1.      ]
#  [-1.1385    4.6973   -1.      ]
#  [-2.5837    2.7697   -1.      ]
# ...

# %%
a=[[1],[1],[2],[3],[2]]
print(np.unique(a))
# Out:
# [1 2 3]
